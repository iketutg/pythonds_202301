# %% [markdown]
# # Hacktiv8-PTP Python For Data Science // S.4 // Pandas

# %% [markdown]
# ## Komponen dan aplikasi panda
#   library pandas terdiri dari komponen-komponen

# %% [markdown]
# - pandas/core: Ini berisi implementasi dari struktur data dasar panda, seperti Series dan DataFrames. Series dan DataFrames adalah kumpulan alat dasar yang sangat berguna untuk manipulasi data dan digunakan secara luas oleh ilmuwan data.
#
# - pandas/src: Ini terdiri dari algoritma yang menyediakan fungsionalitas dasar panda. Fungsionalitas ini adalah bagian dari arsitektur panda, yang tidak akan Anda gunakan secara eksplisit. Lapisan ini ditulis dalam C atau Cython.
#
# - pandas/io: Ini terdiri dari kumpulan alat untuk input dan output file dan data. Kumpulan alat ini memfasilitasi input data dari sumber seperti CSV dan teks dan memungkinkan Anda menulis data ke format seperti teks dan CSV.
#
# - pandas/tools: Lapisan ini berisi semua kode dan algoritma untuk fungsi dan metode panda, seperti merge, join, dan concat.
#
# - pandas/sparse: Ini berisi fungsionalitas untuk menangani nilai yang hilang dalam struktur datanya, seperti DataFrames dan Series.
#
# - pandas/stats: Ini berisi seperangkat alat untuk menangani fungsi statistik seperti regresi dan klasifikasi.
#
# - pandas/util: Ini berisi semua utilitas untuk men-debug perpustakaan.
#
# - pandas/rpy: Ini adalah antarmuka untuk menghubungkan ke R.

# %% [markdown]
# ## Objek Seri
#
# Dalam panda, data satu dimensi direpresentasikan sebagai objek Seri. Objek seri diinisialisasi menggunakan pd.Series() konstruktor.

# %% [markdown]
# * Series sangat mirip dengan array NumPy (sebenarnya dibangun di atas object array NumPy).
# * Apa yang membedakan array NumPy dari series adalah bahwa series dapat memiliki axis label, artinya dapat di indeks oleh label, bukan hanya lokasi nomor.
# * Itu juga tidak perlu menyimpan data numerik, bisa menampung apa saja python object.

# %%
pip install pandas

# %%
import pandas as pd

# %% [markdown]
# the numbers to the left of the Series (0, 1, 2, 3) are its indices.

# %%
ser2 = pd.Series([[10, 20],[30, 40.5,'series'],[50, 55],{'Name':'Tess','Org':'Packt'}])

# %%
ser2

# %%
vars = pd.Series()
print(vars)

# %% [markdown]
# _______

# %%
import pandas as pd
import numpy as np

datanp = np.array(['X','Y','Z','C','B','A'])
data_s = pd.Series(datanp) 
print(data_s)
# Out:
# 0    X
# 1    Y
# 2    Z
# 3    C
# 4    B
# 5    A
# dtype: object

# %%
datanp1 = np.array(['X','Y','Z','C','B','A'])
data_s1 = pd.Series(datanp1,index=[10,12,13,14,15,16]) 
print(data_s1)
# Out:
# 10    X
# 12    Y
# 13    Z
# 14    C
# 15    B
# 16    A
# dtype: object

# %%
data_dict = {'A':0.7, 'B':2.,'C':10, 'D':1.5} 
data_s2 = pd.Series(data_dict)
print(data_s2)
# Out:
# A     0.7
# B     2.0
# C    10.0
# D     1.5
# dtype: float64

# %%
data_s2 = pd.Series(data_dict,index=['A','B','E',14])
print(data_s2)
# Out:
# A     0.7
# B     2.0
# E     NaN
# 14    NaN
# dtype: float64

# %%
data_s3 = pd.Series(10, index=[1, 2, 3, 4, 5, 6, 7, 8, 9])
print(data_s3)
# Out:
# 1    10
# 2    10
# 3    10
# 4    10
# 5    10
# 6    10
# 7    10
# 8    10
# 9    10
# dtype: int64

# %%
data_np = np.array(['a','b','c','d','e','f'])
print(data_np)

dtsn = pd.Series(data_np)
# Out:
# ['a' 'b' 'c' 'd' 'e' 'f']

# %%
print(dtsn[0:3])
print(dtsn[:4])
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
npr = np.array([10,20,30,40,50,60,70])
pds = pd.Series(npr,index=['a','b','c','d','e','f','g']) 
print(pds)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# dtype: int64

# %%
print(pds['a'])

print(pds['d'])

print(pds['d':'f'])
# Out:
# 10
# 40
# d    40
# e    50
# f    60
# dtype: int64

# %%
print(pds.index)
print(pds.values)
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g'], dtype='object')
# [10 20 30 40 50 60 70]

# %%
dats = pd.Series([1,2,3,4,5,6],index=[1,2,5,6,8,9]) #
print(dats)
print(dats.index)
# Out:
# 1    1
# 2    2
# 5    3
# 6    4
# 8    5
# 9    6
# dtype: int64
# Int64Index([1, 2, 5, 6, 8, 9], dtype='int64')

# %%
print(dats.loc[5])
print("=="*10)
print(dats.loc[2:6])
print("=="*10)
print(dats.loc[[2,6,9]])
# Out:
# 3
# ...
# 2    2
# 5    3
# 6    4
# dtype: int64
# ...
# 2    2
# 6    4
# 9    6
# dtype: int64

# %%
print(dats.values)
print(dats.values >= 4 )

################################################################
print('#'*30)
kodisi = dats.values >= 4
print(dats.loc[kodisi])
# Out:
# [1 2 3 4 5 6]
# [False False False  True  True  True]
# ##############################
# 6    4
# 8    5
# 9    6
# dtype: int64

# %%
print(dats)
# Out:
# 1    1
# 2    2
# 5    3
# 6    4
# 8    5
# 9    6
# dtype: int64

# %%
print(dats.iloc[2])

print(dats.iloc[3])
# Out:
# 3
# 4

# %% [markdown]
# ---------

# %% [markdown]
# ## DataFrames

# %% [markdown]
#  DataFrame adalah representasi data dua dimensi dalam baris dan kolom, yang dapat diinisialisasi dalam panda menggunakan DataFrame()konstruktor.
#
#  DataFrames sangat bagus untuk merepresentasikan data nyata:
#         baris sesuai dengan instance (objek, observasi, dll.), dan kolom sesuai
#         dengan features untuk setiap instance.

# %%
import pandas as pd

# %%
datadict = { 'name': ['Joko','Joni','Jono','John'], 
             'age':[30,50,20,40],
             'address':['Solo','Bandung','Jakarta','London'], 
             'qualification' : ['Msc','MA','Ir','Phd']
            }

print(datadict)
# Out:
# {'name': ['Joko', 'Joni', 'Jono', 'John'], 'age': [30, 50, 20, 40], 'address': ['Solo', 'Bandung', 'Jakarta', 'London'], 'qualification': ['Msc', 'MA', 'Ir', 'Phd']}

# %%
df = pd.DataFrame(datadict) 
print(df)
# Out:
#    name  age  address qualification
# 0  Joko   30     Solo           Msc
# 1  Joni   50  Bandung            MA
# 2  Jono   20  Jakarta            Ir
# 3  John   40   London           Phd

# %%
print(df[['name','qualification']])
# Out:
#    name qualification
# 0  Joko           Msc
# 1  Joni            MA
# 2  Jono            Ir
# 3  John           Phd

# %%
 df['qualification'] == 'Phd'
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# Name: qualification, dtype: bool

# %%
kondisi1 = df['qualification'] == 'Phd'
print(df.loc[df['qualification'] == 'Phd'])
# Out:
#    name  age address qualification
# 3  John   40  London           Phd

# %%
dfangka = pd.DataFrame({'x':[1,2], 'y':[10,30]})
print(dfangka)
# Out:
#    x   y
# 0  1  10
# 1  2  30

# %%
dfl = dfangka.apply(lambda y:y * 3)
print(dfl)
# Out:
#    x   y
# 0  3  30
# 1  6  90

# %%
def square(x):
    return x * x

# %%
dfsquare = dfangka.apply(square) 
print(dfangka)
print('#'*30)
print(dfsquare)
# Out:
#    x   y
# 0  1  10
# 1  2  30
# ##############################
#    x    y
# 0  1  100
# 1  4  900

# %% [markdown]
# _________

# %%
url = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/nba-elo/nbaallelo.csv'

# %%
pip install requests

# %%
import requests

# %%
response = requests.get(url)

# %%
print(type(response))

# %%
print(response.status_code)

# %%
print(response.content)

# %%
with open('nba_elo.csv','wb') as f:
    f.write(response.content)

# %% [markdown]
# |notes    | loc    |
# |:--------|:-------|
# |a value   | ```loc['label'] or loc[0]``` <br> single label or integer  |
# |a list |  ```loc[['label','label2]] ```  <br>  A list of labe      |
# | slicing |  ```loc[['A':'B']] ```  <br> A and B Include     |
# | Condition |   bool series or list        |
# | Callable function | ```loc[lambda A: A[2]] ```          |

# %% [markdown]
# _______

# %%
import pandas as pd 
import numpy as np

pd.__version__
# Out:
# '1.5.3'

# %%
df = pd.read_csv("nba_elo.csv")

# %%
len(df)
# Out:
# 126314

# %%
df.shape
# Out:
# (126314, 23)

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
df.head(10)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  ...  win_equiv  opp_id      opp_fran  \
# 0            0     TRH       Huskies  ...  40.294830     NYK        Knicks
# ...

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126309         100            1     CLE  Cavaliers  ...  60.309792     GSW
# 126310         102            1     GSW   Warriors  ...  68.013329     CLE
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# ...

# %%
pd.set_option("display.max.columns",None) # keselurahan colum

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
pd.set_option("display.precision",2)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %% [markdown]
# |Header	|Definition|
# |:-----|:-------|
# |gameorder|	Play order of game in NBA history |
# | game_id	| Unique ID for each game |
# |lg_id	| Which league the game was played in |
# | `_iscopy` | 	Each row of data is tied to a single team for a single game, so `_iscopy` flags if this game_id has already occured for the opposing team in the same matchup
# | year_id	| Season id, named based on year in which the season ended |
# | date_game	| Game date |
# | is_playoffs	| Flag for playoff games |
# | team_id	| Three letter code for team name, from Basketball Reference |
# | fran_id	| Franchise id. Multiple team_ids can fall under the same fran_id due to name changes or moves. Interactive is grouped by fran_id.
# | pts |	Points scored by team |
# | elo_i	| Team elo entering the game |
# | elo_n	| Team elo following the game |
# | win_equiv	| Equivalent number of wins in a 82-game season for a team of elo_n quality |
# | opp_id |	Team id of opponent |
# | opp_fran |	Franchise id of opponent |
# | opp_pts |	Points scored by opponent / point pertandingan |
# | opp_elo_i	 | Opponent elo entering the game, sebagai team lawan (Elo sebelum main ) |
# | opp_elo_n	| Opponent elo following the game, sebagai team lawan (Elo setelah main) |
# | game_location	| Home (H), away (A), or neutral (N) |
# | game_result |	Win or loss for team in the team_id column |
# | forecast |	Elo-based chances of winning for the team in the team_id column, based on elo  ratings and game location
# |notes|	Additional informatio |

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
df['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df['fran_id'].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
df['fran_id'] == 'Lakers'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309    False
# 126310    False
# 126311    False
# 126312    False
# 126313    False
# Name: fran_id, Length: 126314, dtype: bool

# %%
df.loc[df['fran_id'] == 'Lakers']
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1136          569  194811040BLB   NBA        1     1949   11/4/1948
# 1152          577  194811060WSC   NBA        1     1949   11/6/1948
# 1159          580  194811090BOS   NBA        1     1949   11/9/1948
# 1170          586  194811110NYK   NBA        1     1949  11/11/1948
# 1183          592  194811130PRO   NBA        1     1949  11/13/1948
# ...           ...           ...   ...      ...      ...         ...
# 126016      63009  201504080DEN   NBA        1     2015    4/8/2015
# 126052      63027  201504100LAL   NBA        0     2015   4/10/2015
# 126086      63044  201504120LAL   NBA        0     2015   4/12/2015
# 126115      63058  201504130SAC   NBA        1     2015   4/13/2015
# 126137      63069  201504150LAL   NBA        0     2015   4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 1136             1            0     MNL  Lakers   84  1527.00  1542.25
# ...

# %%
df.loc[df['fran_id'] == 'Lakers',"team_id"]
# Out:
# 1136      MNL
# 1152      MNL
# 1159      MNL
# 1170      MNL
# 1183      MNL
#          ...
# 126016    LAL
# 126052    LAL
# 126086    LAL
# 126115    LAL
# 126137    LAL
# Name: team_id, Length: 6024, dtype: object

# %%
df.loc[df['fran_id'] == 'Lakers',"team_id"].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.loc[df['team_id'] == 'MNL',"date_game"].value_counts()
# Out:
# 11/4/1948     1
# 11/15/1956    1
# 3/16/1956     1
# 3/17/1956     1
# 3/19/1956     1
#              ..
# 11/29/1952    1
# 11/30/1952    1
# 12/1/1952     1
# 12/3/1952     1
# 3/26/1960     1
# Name: date_game, Length: 946, dtype: int64

# %%
df.loc[df['team_id'] == 'MNL',"date_game"].max()
# Out:
# '4/9/1959'

# %%
df['date_played']= pd.to_datetime(df['date_game'])

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.loc[df['team_id']=='MNL','date_game'].max()
# Out:
# '4/9/1959'

# %%
df.loc[df['team_id']=='MNL','date_played'].max() # date_played is type datetime
# Out:
# Timestamp('1960-03-26 00:00:00')

# %%
df.loc[df['team_id']=='MNL','date_game'].min()  # date_game type string
# Out:
# '1/1/1949'

# %%
df.loc[df['team_id']=='MNL','date_played'].min()
# Out:
# Timestamp('1948-11-04 00:00:00')

# %%
df.loc[df['team_id']=='MNL','date_played'].agg(('min','max'))
# Out:
# min   1948-11-04
# max   1960-03-26
# Name: date_played, dtype: datetime64[ns]

# %%
df['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
df.loc[df['team_id'] == 'BOS', "pts"].sum()
# Out:
# 626484

# %%
df.loc[df['team_id'] == 'BOS', "date_played"]
# Out:
# 6        1946-11-02
# 14       1946-11-05
# 28       1946-11-09
# 40       1946-11-13
# 46       1946-11-14
#             ...
# 126141   2015-04-15
# 126162   2015-04-19
# 126173   2015-04-21
# 126185   2015-04-23
# 126205   2015-04-26
# Name: date_played, Length: 5997, dtype: datetime64[ns]

# %%
df.loc[df['team_id'] == 'BOS', "date_played"].apply(lambda y: y.year)
# Out:
# 6         1946
# 14        1946
# 28        1946
# 40        1946
# 46        1946
#           ...
# 126141    2015
# 126162    2015
# 126173    2015
# 126185    2015
# 126205    2015
# Name: date_played, Length: 5997, dtype: int64

# %%
df.loc[df['team_id'] == 'BOS', "date_played"].apply(lambda x: x.year).unique()
# Out:
# array([1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#        1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#        1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#        1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015])

# %%
# kita menyiapkan variable total point boston 

total_bos_point = df.loc[df['team_id'] == 'BOS', "pts"].sum()
print(total_bos_point)
# Out:
# 626484

# %%
tahun_main_bos = len(df.loc[df['team_id'] == 'BOS', "date_played"].apply(lambda x: x.year).unique())
print(tahun_main_bos)
# Out:
# 70

# %%
# rata rata tahun boston
total_bos_point / tahun_main_bos
# Out:
# 8949.771428571428

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes',
#         'date_payed', 'date_played'],
#        dtype='object')]

# %%
df.axes[0]
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
"points" in df.keys()
# Out:
# False

# %%
"pts" in df.keys()
# Out:
# True

# %% [markdown]
# * .loc
# * .iloc
#
#
# |notes    | loc    | iloc |
# |:--------|:-------|:-----|
# |a value   | ```loc['label'] or loc[0]``` <br> single label or integer  |```iloc[1]``` single integer |
# |a list |  ```loc[['label','label2]] ```  <br>  A list of labe | ``` iloc[[1,2,3]]``` list integers
# | slicing |  ```loc[['A':'B']] ```  <br> A and B Include     | ``` iloc[n:m]```, n is include m exclude |
# | Condition |   bool series or list        | bool list |
# | Callable function | ```loc[lambda A: A[2]] ```  |  ```iloc[lambda A: A[2]] ``` |

# %% [markdown]
# ## Query data set

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
decade = df[df['year_id'] > 2010]
print(decade)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# ...

# %%
decade.shape
# Out:
# (12658, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 25 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df['notes'].notnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126309    False
# 126310    False
# 126311    False
# 126312    False
# 126313    False
# Name: notes, Length: 126314, dtype: bool

# %%
games_notes = df[df['notes'].notnull()]
print(games_notes)
print(games_notes.shape)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# ...

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %% [markdown]
# ______

# %%
team_tail_ers = df[df['fran_id'].str.endswith('ers')]
print(team_tail_ers)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 16              9  194611050DTF   NBA        1     1947  11/5/1946
# 20             11  194611070PRO   NBA        0     1947  11/7/1946
# 22             12  194611070STB   NBA        0     1947  11/7/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 7                1            0     PRO  Steamrollers   59  1300.00  1305.15
# ...

# %%
team_tail_ers.shape
# Out:
# (27797, 25)

# %% [markdown]
# _____

# %%
df[(df['team_id'] == 'BLB')  &  (df['pts']>100)  &  (df['opp_pts']>100)]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949  2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
# 5825       2913  195402220BLB   NBA        0     1954  2/22/1954          60
#
#       is_playoffs team_id    fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 1726            0     BLB  Baltimore  114  1421.94  1419.43      38.56    MNL
# 4890            0     BLB  Baltimore  126  1328.67  1356.65      25.80    BOS
# 4909            0     BLB  Baltimore  104  1349.83  1346.36      24.88    MNL
# 5208            0     BLB  Baltimore  107  1284.52  1282.24      19.58    NYK
# 5825            0     BLB  Baltimore  110  1303.75  1301.97      20.74    BOS
#
# ...

# %%
group_fran = df.groupby('fran_id', sort=False)
print(group_fran)

# %%
group_fran['pts'].sum()
# Out:
# fran_id
# Huskies           3995
# Knicks          582497
# Stags            20398
# Falcons           3797
# Capitols         22387
# Celtics         626484
# Steamrollers     12372
# Ironmen           3674
# Bombers          17793
# Rebels            4474
# Warriors        591224
# Baltimore        37219
# Jets              4482
# Pistons         572758
# Lakers          637444
# Kings           569245
# Hawks           567261
# Denver            4818
# Olympians        22864
# Redskins          5372
# Waterloo          4921
# Packers           6193
# Sixers          585891
# Wizards         474809
# Bulls           437269
# Thunder         437735
# Squires          91127
# Stars            84940
# Rockets         432504
# Colonels         94435
# Pacers          438288
# Nuggets         445780
# Spurs           453822
# Spirits          85874
# Sounds           75582
# Floridians       49568
# Nets            417809
# Condors          49642
# Bucks           418326
# ...

# %%
hasil_tahun = df[df['fran_id'] == 'Bulls'].groupby(['year_id','game_result'])
print(hasil_tahun)

# %%
hasil_tahun['game_id'].count()
# Out:
# year_id  game_result
# 1967     L              51
#          W              33
# 1968     L              57
#          W              30
# 1969     L              49
#                         ..
# 2013     W              50
# 2014     L              38
#          W              49
# 2015     L              38
#          W              56
# Name: game_id, Length: 98, dtype: int64

# %%
df[(df['fran_id'] == 'Spurs') & (df['year_id'] > 2010)]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113684      56843  201010270SAS   NBA        0     2011  10/27/2010
# 113733      56867  201010300SAS   NBA        0     2011  10/30/2010
# 113744      56873  201011010LAC   NBA        1     2011   11/1/2010
# 113778      56890  201011030PHO   NBA        1     2011   11/3/2010
# 113824      56913  201011060SAS   NBA        0     2011   11/6/2010
# ...           ...           ...   ...      ...      ...         ...
# 126192      63097  201504240SAS   NBA        0     2015   4/24/2015
# 126209      63105  201504260SAS   NBA        0     2015   4/26/2015
# 126221      63111  201504280LAC   NBA        1     2015   4/28/2015
# 126228      63115  201504300SAS   NBA        0     2015   4/30/2015
# 126233      63117  201505020LAC   NBA        1     2015    5/2/2015
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 113684           1            0     SAS   Spurs  122  1594.28  1599.31
# ...

# %%
[ df[(df['fran_id'] == 'Spurs') & 
(df['year_id'] > 2010)]
.groupby(["year_id","game_result"])['game_id'].count() ]
# Out:
# [year_id  game_result
#  2011     L              25
#           W              63
#  2012     L              20
#           W              60
#  2013     L              30
#           W              73
#  2014     L              27
#           W              78
#  2015     L              31
#           W              58
#  Name: game_id, dtype: int64]

# %%
nba = df.copy() 
nba.shape
# Out:
# (126314, 25)

# %%
nba['pts'] - nba['opp_pts']
# Out:
# 0         -2
# 1          2
# 2         16
# 3        -16
# 4        -17
#           ..
# 126309   -21
# 126310    13
# 126311   -13
# 126312    -8
# 126313     8
# Length: 126314, dtype: int64

# %%
nba['difference'] = df.pts - df.opp_pts

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
nba['difference'].max()
# Out:
# 68

# %%
nba['difference'].min()
# Out:
# -68

# %%
df.elo_i - df.opp_elo_i
# Out:
# 0           0.00
# 1           0.00
# 2          -6.72
# 3           6.72
# 4           0.00
#            ...
# 126309    -67.54
# 126310    105.58
# 126311   -105.58
# 126312   -112.90
# 126313    112.90
# Length: 126314, dtype: float64

# %%
nba['elo_difference'] = df.elo_i - df.opp_elo_i

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
nba.shape
# Out:
# (126314, 27)

# %%
nba['elo_difference'].max()
# Out:
# 572.1608999999999

# %%
nba['elo_difference'].argmin()
# Out:
# 23538

# %%
nba['elo_difference'].argmax()
# Out:
# 23539

# %%
nba.rename( 
    columns={
        "game_result" : "result",
        "game_location" : "location"
    }
)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
nba.rename( 
    columns={
        "game_result" : "result",
        "game_location" : "location"
    }, inplace=True
)

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
nba.shape
# Out:
# (126314, 27)

# %% [markdown]
# axis : {0 or 'index', 1 or 'columns'}, default 0

# %%
elo_column = ['elo_i','elo_n','opp_elo_i','opp_elo_n']
nba.drop(elo_column) # default 0 or indexs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[203], line 2
#       1 elo_column = ['elo_i','elo_n','opp_elo_i','opp_elo_n']
# ----> 2 nba.drop(elo_column)
#
# File /usr/local/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
nba2 = nba.drop(elo_column,axis=1) # default 0 or indexs

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
nba2
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
nba.drop(elo_column,axis=1,inplace=True) # default 0 or indexs

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
nba.shape
# Out:
# (126314, 23)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   gameorder       126314 non-null  int64
#  1   game_id         126314 non-null  object
#  2   lg_id           126314 non-null  object
#  3   _iscopy         126314 non-null  int64
#  4   year_id         126314 non-null  int64
#  5   date_game       126314 non-null  object
#  6   seasongame      126314 non-null  int64
#  7   is_playoffs     126314 non-null  int64
#  8   team_id         126314 non-null  object
#  9   fran_id         126314 non-null  object
#  10  pts             126314 non-null  int64
#  11  win_equiv       126314 non-null  float64
#  12  opp_id          126314 non-null  object
#  13  opp_fran        126314 non-null  object
#  14  opp_pts         126314 non-null  int64
#  15  location        126314 non-null  object
# ...

# %%
row_no_missing = nba.dropna()

# %%
print(row_no_missing.shape)
# Out:
# (5424, 23)

# %%
column_missing = nba.dropna(axis=1)

# %%
column_missing.shape
# Out:
# (126314, 22)

# %%
column_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 22 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   gameorder       126314 non-null  int64
#  1   game_id         126314 non-null  object
#  2   lg_id           126314 non-null  object
#  3   _iscopy         126314 non-null  int64
#  4   year_id         126314 non-null  int64
#  5   date_game       126314 non-null  object
#  6   seasongame      126314 non-null  int64
#  7   is_playoffs     126314 non-null  int64
#  8   team_id         126314 non-null  object
#  9   fran_id         126314 non-null  object
#  10  pts             126314 non-null  int64
#  11  win_equiv       126314 non-null  float64
#  12  opp_id          126314 non-null  object
#  13  opp_fran        126314 non-null  object
#  14  opp_pts         126314 non-null  int64
#  15  location        126314 non-null  object
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   gameorder       126314 non-null  int64
#  1   game_id         126314 non-null  object
#  2   lg_id           126314 non-null  object
#  3   _iscopy         126314 non-null  int64
#  4   year_id         126314 non-null  int64
#  5   date_game       126314 non-null  object
#  6   seasongame      126314 non-null  int64
#  7   is_playoffs     126314 non-null  int64
#  8   team_id         126314 non-null  object
#  9   fran_id         126314 non-null  object
#  10  pts             126314 non-null  int64
#  11  win_equiv       126314 non-null  float64
#  12  opp_id          126314 non-null  object
#  13  opp_fran        126314 non-null  object
#  14  opp_pts         126314 non-null  int64
#  15  location        126314 non-null  object
# ...

# %%
data_notes = nba.copy()

# %%
data_notes['notes'].fillna(value="Salah input",inplace=True)

# %%
data_notes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   gameorder       126314 non-null  int64
#  1   game_id         126314 non-null  object
#  2   lg_id           126314 non-null  object
#  3   _iscopy         126314 non-null  int64
#  4   year_id         126314 non-null  int64
#  5   date_game       126314 non-null  object
#  6   seasongame      126314 non-null  int64
#  7   is_playoffs     126314 non-null  int64
#  8   team_id         126314 non-null  object
#  9   fran_id         126314 non-null  object
#  10  pts             126314 non-null  int64
#  11  win_equiv       126314 non-null  float64
#  12  opp_id          126314 non-null  object
#  13  opp_fran        126314 non-null  object
#  14  opp_pts         126314 non-null  int64
#  15  location        126314 non-null  object
# ...

# %%
pip install matplotlib
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 15.7 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 8.4 MB/s eta 0:00:00
# ...
#   Using cached kiwisolver-1.4.4-cp39-cp39-macosx_10_9_x86_64.whl (65 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 15.3 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 11.8 MB/s eta 0:00:0000:0100:01
# ...

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66      40.29    NYK    Knicks       68
# 1            0     NYK   Knicks   68      41.71    TRH   Huskies       66
# 2            0     CHS    Stags   63      42.01    NYK    Knicks       47
# 3            0     NYK   Knicks   47      40.69    CHS     Stags       63
# 4            0     DTF  Falcons   33      38.86    WSC  Capitols       50
#
#   location result  forecast notes date_payed date_played  difference  \
# ...

# %%
nba[nba['fran_id'] == "knight"]
# Out:
# Empty DataFrame
# Columns: [gameorder, game_id, lg_id, _iscopy, year_id, date_game, seasongame, is_playoffs, team_id, fran_id, pts, win_equiv, opp_id, opp_fran, opp_pts, location, result, forecast, notes, date_payed, date_played, difference, elo_difference]
# Index: []

# %%
knight_pt_by_thn = nba[nba['fran_id'] == "Knicks"].groupby('year_id')['pts'].sum()

# %%
knight_pt_by_thn
# Out:
# year_id
# 1947    4234
# 1948    3815
# 1949    5253
# 1950    5924
# 1951    6814
#         ...
# 2011    9097
# 2012    6872
# 2013    9259
# 2014    8084
# 2015    7535
# Name: pts, Length: 69, dtype: int64

# %%
knight_pt_by_thn.plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='year_id'>

# %%
nba[   (nba['fran_id'] == 'Heat') & (nba['year_id'] == 2013) ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 nba[   (nba['fran_id'] == 'Heat') & (nba['year_id'] == 2013) ]
#
# NameError: name 'nba' is not defined

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame(np.random.randint(10, size=(5,6)), columns=list("ABCDEF"))
df
# Out:
#    A  B  C  D  E  F
# 0  1  1  8  3  5  5
# 1  4  8  6  4  0  0
# 2  1  1  7  1  1  4
# 3  0  2  6  7  5  6
# 4  1  3  8  0  0  6

# %%
df.query("A > 1")
# Out:
#    A  B  C  D  E  F
# 1  4  8  6  4  0  0

# %%
df.query("A > 1 and E == 0")
# Out:
#    A  B  C  D  E  F
# 1  4  8  6  4  0  0

# %%
df.query("A > 2 or F > 4")
# Out:
#    A  B  C  D  E  F
# 0  1  1  8  3  5  5
# 1  4  8  6  4  0  0
# 3  0  2  6  7  5  6
# 4  1  3  8  0  0  6

# %%
df.query("not (A > 2 or F > 4)")
# Out:
#    A  B  C  D  E  F
# 2  1  1  7  1  1  4

# %%
df.query("A*2 < 5")
# Out:
#    A  B  C  D  E  F
# 0  1  1  8  3  5  5
# 2  1  1  7  1  1  4
# 3  0  2  6  7  5  6
# 4  1  3  8  0  0  6

# %%
df.F = -1 * df.F
df.query("abs(F) > 6")
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E, F]
# Index: []

# %%
df.query("sqrt(A) > 2")
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E, F]
# Index: []

# %%
df["G"] = ["John", "Jane", "Ashley", "Luke", "Michael"]
df.query("G > 'Jo'")
# Out:
#    A  B  C  D  E  F        G
# 0  1  1  8  3  5 -5     John
# 3  0  2  6  7  5 -6     Luke
# 4  1  3  8  0  0 -6  Michael

# %%
df["Date"] = pd.date_range(start="2021-04-05", periods=5, freq="M")
df
# Out:
#    A  B  C  D  E  F        G       Date
# 0  1  1  8  3  5 -5     John 2021-04-30
# 1  4  8  6  4  0  0     Jane 2021-05-31
# 2  1  1  7  1  1 -4   Ashley 2021-06-30
# 3  0  2  6  7  5 -6     Luke 2021-07-31
# 4  1  3  8  0  0 -6  Michael 2021-08-31

# %%
df.query("Date.dt.month > 6")
# Out:
#    A  B  C  D  E  F        G       Date
# 3  0  2  6  7  5 -6     Luke 2021-07-31
# 4  1  3  8  0  0 -6  Michael 2021-08-31

# %%
df.query("A + B < C")
# Out:
#    A  B  C  D  E  F        G       Date
# 0  1  1  8  3  5 -5     John 2021-04-30
# 2  1  1  7  1  1 -4   Ashley 2021-06-30
# 3  0  2  6  7  5 -6     Luke 2021-07-31
# 4  1  3  8  0  0 -6  Michael 2021-08-31

# %% [markdown]
# ------------

# %% [markdown]
# 1. Create pandas DataFrame from Dict (Dictionary)

# %%
# Dict object
courses = {'Courses':['Spark','PySpark','Java','PHP'],
           'Fee':[20000,20000,15000,10000],
           'Duration':['35days','35days','40days','30days']}

# Create DataFrame from dict
df = pd.DataFrame.from_dict(courses)
print(df)
# Out:
#    Courses    Fee Duration
# 0    Spark  20000   35days
# 1  PySpark  20000   35days
# 2     Java  15000   40days
# 3      PHP  10000   30days

# %%
index=['r0','r1','r2','r3']
# Create DataFrame with index
df = pd.DataFrame.from_dict(courses,index=index)

# set index to existing DataFrame
df.set_index(index, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 index=['r0','r1','r2','r3']
#       2 # Create DataFrame with index
# ----> 3 df = pd.DataFrame.from_dict(courses,index=index)
#       5 # set index to existing DataFrame
#       6 df.set_index(index, inplace=True)
#
# TypeError: from_dict() got an unexpected keyword argument 'index'

# %% [markdown]
# 3. Create from Dict with Selected Columns

# %% [markdown]
# _________________

# %%
import pandas as pd

# create a sample dataframe
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Dave'],
    'Age': [25, 32, 18, 47],
    'City': ['New York', 'Paris', 'London', 'Tokyo']
}
df = pd.DataFrame(data)

# set the 'Name' column as the index
df = df.set_index('Name')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Alice to Dave
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     4 non-null      int64
#  1   City    4 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 96.0+ bytes

# %%
# create a sample dataframe
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Dave'],
    'Age': [25, 32, 18, 47],
    'City': ['New York', 'Paris', 'London', 'Tokyo']
}
df1 = pd.DataFrame(data)

# %%
# set the 'Name' and 'City' columns as the index
df1 = df1.set_index(['Name', 'City'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 4 entries, ('Alice', 'New York') to ('Dave', 'Tokyo')
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     4 non-null      int64
# dtypes: int64(1)
# memory usage: 554.0+ bytes

# %%
import pandas as pd

# Membuat contoh dataframe dalam format long
df_long = pd.DataFrame({
    'Provinsi' : ["A", "A", "A", "B", "B", "B", 
                  "C", "C", "C", "D", "D", "D"], 
    'Tahun' : ["2019", "2020", "2021", "2019", "2020", "2021", 
               "2019", "2020", "2021",  "2019", "2020", "2021"], 
    'Growth' : [3.6, 5.1, 4.7, 2.8, 4.4, 3.9, 
                6.1, 4.8, 4.2, 2.9, 4.7, 3.4]
})

# %%
# Menampilkan df_long

df_long
# Out:
#    Provinsi Tahun  Growth
# 0         A  2019     3.6
# 1         A  2020     5.1
# 2         A  2021     4.7
# 3         B  2019     2.8
# 4         B  2020     4.4
# 5         B  2021     3.9
# 6         C  2019     6.1
# 7         C  2020     4.8
# 8         C  2021     4.2
# 9         D  2019     2.9
# 10        D  2020     4.7
# 11        D  2021     3.4

# %%
# Reformat df_long menjadi wide
df_wide = pd.pivot(df_long, index='Provinsi', 
                   columns='Tahun', values='Growth')

# Menampilkan df_wide
df_wide
# Out:
# Tahun     2019  2020  2021
# Provinsi
# A          3.6   5.1   4.7
# B          2.8   4.4   3.9
# C          6.1   4.8   4.2
# D          2.9   4.7   3.4

# %%
# Reformat df_long menjadi wide
df_wide = pd.pivot(df_long, index='Tahun', 
                   columns='Provinsi', values='Growth')
# Menampilkan df_wide
df_wide
# Out:
# Provinsi    A    B    C    D
# Tahun
# 2019      3.6  2.8  6.1  2.9
# 2020      5.1  4.4  4.8  4.7
# 2021      4.7  3.9  4.2  3.4

# %%
# Membuat contoh dataframe dalam format long
df_long = pd.DataFrame({
    'Provinsi' : ["A", "A", "A", "A", "A", "A", 
                  "B", "B", "B", "B", "B", "B", 
                  "C", "C", "C", "C", "C", "C" ], 
    'Tahun' : ["2019", "2019", "2020", "2020", "2021", "2021", 
               "2019", "2019", "2020", "2020", "2021", "2021", 
               "2019", "2019", "2020", "2020", "2021", "2021" ], 
    'Semester' : [1, 2, 1, 2, 1, 2, 
                  1, 2, 1, 2, 1, 2, 
                  1, 2, 1, 2, 1, 2],
    'Growth' : [3.1, 4.1, 4.3, 2.7, 4.5, 3.4, 
                4.7, 2.4, 4.4, 3.9, 3.2, 5.4, 
                3.7, 3.9, 4.5, 3.8, 4.1, 2.3]
})
# Reformat df_long menjadi wide
df_wide = pd.pivot(df_long, index='Provinsi', 
                   columns=['Tahun', 'Semester'], values='Growth')

# %%
df_wide
# Out:
# Tahun    2019      2020      2021
# Semester    1    2    1    2    1    2
# Provinsi
# A         3.1  4.1  4.3  2.7  4.5  3.4
# B         4.7  2.4  4.4  3.9  3.2  5.4
# C         3.7  3.9  4.5  3.8  4.1  2.3

# %% [markdown]
# _____

# %% [markdown]
# ### Melt / Wide to Long

# %%
import pandas as pd

# Membuat contoh dataframe dalam format wide
df_wide = pd.DataFrame({'Nama' : ['Andi', 'Budi', 'Candra', 'Dina'],
                        'Matematika' : [90, 70, 85, 69],
                        'B_Indonesia' : [76, 78, 94, 86],
                        'B_Inggris' : [72, 84, 88, 97],
                        'Kesenian' : [82, 90, 83, 89]})

# Menampilkan df_wide
df_wide
# Out:
#      Nama  Matematika  B_Indonesia  B_Inggris  Kesenian
# 0    Andi          90           76         72        82
# 1    Budi          70           78         84        90
# 2  Candra          85           94         88        83
# 3    Dina          69           86         97        89

# %%
# Reformat wide menjadi long
df_long = pd.melt(df_wide, id_vars='Nama', 
                  value_vars=['Matematika', 'B_Indonesia',  
                              'B_Inggris', 'Kesenian'],
                  var_name='Mata_Pelajaran',
                  value_name='Skor_Ujian')

# Menampilkan df_long
df_long
# Out:
#       Nama Mata_Pelajaran  Skor_Ujian
# 0     Andi     Matematika          90
# 1     Budi     Matematika          70
# 2   Candra     Matematika          85
# 3     Dina     Matematika          69
# 4     Andi    B_Indonesia          76
# 5     Budi    B_Indonesia          78
# 6   Candra    B_Indonesia          94
# 7     Dina    B_Indonesia          86
# 8     Andi      B_Inggris          72
# 9     Budi      B_Inggris          84
# 10  Candra      B_Inggris          88
# 11    Dina      B_Inggris          97
# 12    Andi       Kesenian          82
# 13    Budi       Kesenian          90
# 14  Candra       Kesenian          83
# 15    Dina       Kesenian          89
